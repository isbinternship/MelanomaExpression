# %%
import os

os.chdir('/Users/user/melanoma_training')

currentDir = 'gdc_download'

fileList = os.listdir(currentDir)

i = 1
#print(f)

for x in fileList:
    #h = os.path.isfile(x)
    if os.path.isfile(x) == True:
        continue
    
    tempName = "Case_" + str(i)
    
    
    # %pwd
    
    src = os.path.join(currentDir, x) 
    dst = os.path.join(currentDir, tempName)
    
    print(src, dst)
    
    #os.rename(src, dst)
    
    i += 1 
    
#print(f)
# Out:
# ('gdc_download/Case_56', 'gdc_download/Case_1')
# ('gdc_download/Case_247', 'gdc_download/Case_2')
# ('gdc_download/Case_411', 'gdc_download/Case_3')
# ('gdc_download/Case_69', 'gdc_download/Case_4')
# ('gdc_download/Case_278', 'gdc_download/Case_5')
# ('gdc_download/Case_416', 'gdc_download/Case_6')
# ('gdc_download/Case_240', 'gdc_download/Case_7')
# ('gdc_download/Case_51', 'gdc_download/Case_8')
# ('gdc_download/Case_429', 'gdc_download/Case_9')
# ('gdc_download/Case_93', 'gdc_download/Case_10')
# ('gdc_download/Case_276', 'gdc_download/Case_11')
# ('gdc_download/Case_420', 'gdc_download/Case_12')
# ('gdc_download/Case_67', 'gdc_download/Case_13')
# ('gdc_download/Case_282', 'gdc_download/Case_14')
# ('gdc_download/Case_249', 'gdc_download/Case_15')
# ('gdc_download/Case_58', 'gdc_download/Case_16')
# ('gdc_download/Case_60', 'gdc_download/Case_17')
# ('gdc_download/Case_285', 'gdc_download/Case_18')
# ('gdc_download/Case_427', 'gdc_download/Case_19')
# ...

# %%
# %pwd
# Out:
# u'/Users/user/melanoma_training'
